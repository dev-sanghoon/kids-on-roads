# %%
import os
import zipfile
from ultralytics import YOLO

# %%
model = YOLO("yolov8n-seg.pt")
results = model.train(data='data/data.yaml', epochs=300, imgsz=640, save=True)
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 115MB/s]
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()

# %%
metrics.seg.map
# Out:
# 0.7663810495920612

# %%
tuned_model = YOLO("runs/segment/train/weights/best.pt")

tuned_model("demo-prepare/sample_img.jpg", save=True)

# %%
import cv2

cap = cv2.imread("runs/segment/predict/sample_img.jpg")
cv2.imshow(cap)

# %%
cap.shape
